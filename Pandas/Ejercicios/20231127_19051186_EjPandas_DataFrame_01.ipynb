# %% [markdown]
# # 👨🏽‍💻 Ejercicio Pandas: DataFrame 01

# %% [markdown]
# ##### **Ejercicio** 1️⃣
# Crear un DataFrame que incluya un arreglo matriz aleatorio (0, 101) de orden 5x4, en el cual incluya de índices las monedas de los países, y en las columnas los meses.

# %%
import numpy as np
import pandas as pd
np.random.seed(0)

monedas = ['Peso', 'Dolar', 'Euro', 'Yen', 'Libra']
meses = ['Enero', 'Febrero', 'Marzo', 'Abril']
data = np.random.randint(0, 101, (5, 4))
df = pd.DataFrame(data = data, index = monedas, columns = meses)

# %%
df
# Out:
#        Enero  Febrero  Marzo  Abril
# Peso      44       47     64     67
# Dolar     67        9     83     21
# Euro      36       87     70     88
# Yen       88       12     58     65
# Libra     39       87     46     88

# %% [markdown]
# ##### **Ejercicio** 2️⃣

# %% [markdown]
# - Muestre solo el último renglón.

# %%
df.iloc[-1:]
# Out:
#        Enero  Febrero  Marzo  Abril
# Libra     39       87     46     88

# %% [markdown]
# - Muestre solo la última columna.

# %%
df.iloc[:, -1:]
# Out:
#        Abril
# Peso      67
# Dolar     21
# Euro      88
# Yen       65
# Libra     88

# %% [markdown]
# - Muestre lo que hay en el renglón 3, columna 4.

# %%
df.iloc[2, 3]
# Out:
# 88

# %% [markdown]
# ##### **Ejercicio** 3️⃣
# Encuentre un dataset de Kaggle y muestre lo siguiente:
# - Muestre total de columnas con el atributo «.columns».
# - Muestre la información del DataFrame.
# - Muestre el encabezado para los primeros 5 y 10 renglones.
# - Hacer lo mismo pero ahora para el final de la tabla.

# %%
pwd
# Out:
# 'c:\\Users\\Admin\\Documents\\ITS\\Semestre 9\\Data_Science\\Pandas\\Ejercicios'

# %%
# DataFrame que tome los datos del archivo nuclear_incidents.csv.
nuclear_incidents = pd.read_csv('c:\\Users\\Admin\\Documents\\ITS\\Semestre 9\\Data_Science\\Pandas\\Datasets\\nuclear_incidents.csv')

# %%
# Total de columnas:
nuclear_incidents.columns
# Out:
# Index(['Date', 'Location ', 'Incident', 'Category', 'Numbers of Direct Deaths',
#        'Numbers of InDirect Deaths', 'INES\nlevel', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# Información del DataFrame:
nuclear_incidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        28 non-null     object
#  1   Location                    28 non-null     object
#  2   Incident                    28 non-null     object
#  3   Category                    28 non-null     object
#  4   Numbers of Direct Deaths    26 non-null     float64
#  5   Numbers of InDirect Deaths  3 non-null      object
#  6   INES
# level                  16 non-null     float64
#  7   Latitude                    28 non-null     float64
#  8   Longitude                   28 non-null     float64
# dtypes: float64(4), object(5)
# memory usage: 2.1+ KB

# %%
# Primeros 5 renglones:
nuclear_incidents.head()
# Out:
#          Date                                          Location
# 0  29/09/1957                       Mayak, Kyshtym, Soviet Union  \
# 1  10/10/1957             Sellafield, Cumberland, United Kingdom
# 2  03/01/1961                  Idaho Falls, Idaho, United States
# 3  05/10/1966  Frenchtown Charter Township, Michigan, United ...
# 4  21/01/1969                  Lucens reactor, Vaud, Switzerland
#
#                                       Incident                     Category
# 0                             Kyshtym disaster             Storage/Handling  \
# 1                               Windscale fire  Operational/Safety Measures
# 2                     SL-1 prototype explosion               Operator Error
# 3                     Fermi 1 Reactor meltdown              Technical Flaws
# 4  Loss-of-Coolant Accident (January 21, 1969)               Operator Error
#
#    Numbers of Direct Deaths Numbers of InDirect Deaths  INES\nlevel  Latitude
# ...

# %%
# Primeros 10 renglones:
nuclear_incidents.head(10)
# Out:
#          Date                                          Location
# 0  29/09/1957                       Mayak, Kyshtym, Soviet Union  \
# 1  10/10/1957             Sellafield, Cumberland, United Kingdom
# 2  03/01/1961                  Idaho Falls, Idaho, United States
# 3  05/10/1966  Frenchtown Charter Township, Michigan, United ...
# 4  21/01/1969                  Lucens reactor, Vaud, Switzerland
# 5  07/12/1975                           Greifswald, East Germany
# 6  05/01/1976                 Jaslovské Bohunice, Czechoslovakia
# 7  28/03/1979     Three Mile Island, Pennsylvania, United States
# 8  15/09/1984                     Athens, Alabama, United States
# 9  09/03/1985                     Athens, Alabama, United States
#
#                                       Incident
# 0                             Kyshtym disaster  \
# 1                               Windscale fire
# 2                     SL-1 prototype explosion
# 3                     Fermi 1 Reactor meltdown
# ...

# %%
# Últimos 5 renglones:
nuclear_incidents.tail()
# Out:
#           Date                Location
# 23  10/04/2003            Paks, Hungary  \
# 24  09/08/2004  Fukui Prefecture, Japan
# 25  25/07/2006         Forsmark, Sweden
# 26  11/03/2011         Fukushima, Japan
# 27  12/09/2011         Marcoule, France
#
#                                          Incident
# 23     Paks Nuclear Power Plant fuel rod collapse  \
# 24           Mihama Nuclear Power Plant explosion
# 25  Forsmark Nuclear Power Plant electrical fault
# 26                     Fukushima nuclear disaster
# 27                    Marcoule Nuclear Site blast
#
#                                 Category  Numbers of Direct Deaths
# 23                    Corrosion Cleaning                       0.0  \
# 24                       Steam Explosion                       4.0
# 25                Safety Systems Failure                       0.0
# 26  Natural Disaster/Operational Failure                       4.0
# 27                   Industrial Accident                       1.0
#
# ...

# %%
# Últimos 10 renglones:
nuclear_incidents.tail(10)
# Out:
#           Date                              Location
# 18  01/03/1992  Sosnovy Bor, Leningrad Oblast, Russia  \
# 19  20/02/1996  Waterford, Connecticut, United States
# 20  02/09/1996  Crystal River, Florida, United States
# 21  30/09/1999              Ibaraki Prefecture, Japan
# 22  16/02/2002        Oak Harbor, Ohio, United States
# 23  10/04/2003                          Paks, Hungary
# 24  09/08/2004                Fukui Prefecture, Japan
# 25  25/07/2006                       Forsmark, Sweden
# 26  11/03/2011                       Fukushima, Japan
# 27  12/09/2011                       Marcoule, France
#
#                                          Incident
# 18             Sosnovy Bor nuclear plant accident  \
# 19         Millstone Nuclear Power Plant shutdown
# 20                  Crystal River Unit 3 shutdown
# 21                     Tokaimura nuclear accident
# 22                     Davis-Besse reactor outage
# 23     Paks Nuclear Power Plant fuel rod collapse
# ...
