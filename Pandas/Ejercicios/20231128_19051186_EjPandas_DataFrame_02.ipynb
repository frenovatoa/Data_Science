# %% [markdown]
# # 👨🏽‍💻 Ejercicio Pandas: DataFrame 02

# %% [markdown]
# ##### **Ejercicio** 1️⃣
# Descargue un archivo .csv de (Kaggle)[https://www.kaggle.com/]:
# - Obtenga los 10 primeros renglones.
# - Obtenga los ultimos 10 renglones.
# - Cree una nueva columna con la suma de 2 columnas.
# - Obtenga el valor mínimo de la columna.
# - Obtenga el promedio de la columna.
# - Obtenga la sumatoria de toda la columna.

# %%
# Importar librerías:
import pandas as pd
import numpy as np

# %%
# Crear DataFrame con base en un archivo CSV
# (Coeficiente intelectual global medio por país con otras estadísticas):
avg_iq_per_country = pd.read_csv('c:\\Users\\Admin\\Documents\\ITS\\Semestre 9\\Data_Science\\Pandas\\Datasets\\avg_iq_per_country.csv')

# %%
# Obtener los primeros 10 renglones:
avg_iq_per_country.head(10)
# Out:
#    Rank        Country  Average IQ Continent  Literacy Rate  Nobel Prices  \
# 0     1          Japan      106.48      Asia           0.99            29
# 1     2         Taiwan      106.47      Asia           0.96             4
# 2     3      Singapore      105.89      Asia           0.97             0
# 3     4      Hong Kong      105.37      Asia           0.94             1
# 4     5          China      104.10      Asia           0.96             8
# 5     6    South Korea      102.35      Asia           0.98             0
# 6     7        Belarus      101.60    Europe           1.00             2
# 7     8        Finland      101.20    Europe           1.00             5
# 8     9  Liechtenstein      101.07    Europe           1.00             0
# 9    10        Germany      100.74    Europe           0.99           111
#
#    HDI (2021)  Mean years of schooling - 2021   GNI - 2021 Population - 2023
# 0       0.925                            13.4      42274.0         123294513
# ...

# %%
# Obtener los últimos 10 renglones:
avg_iq_per_country.tail(10)
# Out:
#      Rank          Country  Average IQ        Continent  Literacy Rate  \
# 183   184      South Sudan       58.61           Africa           0.32
# 184   185            Ghana       58.16           Africa           0.77
# 185   186  Costa do Marfim       58.16           Africa           0.43
# 186   187           Guinea       53.48           Africa           0.30
# 187   188        Nicaragua       52.69  Central America           0.82
# 188   189           Gambia       52.68           Africa           0.58
# 189   190        Guatemala       47.72  Central America           0.79
# 190   191          Liberia       45.07           Africa           0.48
# 191   192     Sierra Leone       45.07           Africa           0.48
# 192   193            Nepal       42.99             Asia           0.65
#
#      Nobel Prices  HDI (2021)  Mean years of schooling - 2021   GNI - 2021  \
# 183             0       0.385                             5.7        768.0
# ...

# %%
# Crear una nueva columna con la suma de las columnas 'Average IQ' y 'Nobel Prices':
avg_iq_per_country['Suma'] = avg_iq_per_country['Average IQ'] + avg_iq_per_country['Nobel Prices']
avg_iq_per_country
# Out:
#      Rank       Country  Average IQ        Continent  Literacy Rate  \
# 0       1         Japan      106.48             Asia           0.99
# 1       2        Taiwan      106.47             Asia           0.96
# 2       3     Singapore      105.89             Asia           0.97
# 3       4     Hong Kong      105.37             Asia           0.94
# 4       5         China      104.10             Asia           0.96
# ..    ...           ...         ...              ...            ...
# 188   189        Gambia       52.68           Africa           0.58
# 189   190     Guatemala       47.72  Central America           0.79
# 190   191       Liberia       45.07           Africa           0.48
# 191   192  Sierra Leone       45.07           Africa           0.48
# 192   193         Nepal       42.99             Asia           0.65
#
#      Nobel Prices  HDI (2021)  Mean years of schooling - 2021   GNI - 2021  \
# ...

# %%
# Mínimo de la nueva columna:
avg_iq_per_country['Suma'].min()
# Out:
# 42.99

# %%
# Promedio de la nueva columna:
avg_iq_per_country['Suma'].mean()
# Out:
# 87.97020725388602

# %%
# Suma de la nueva columna:
avg_iq_per_country['Suma'].sum()
# Out:
# 16978.25
